# %% [markdown]
# # 04 – Geração do Relatório

# %%
import sys
from pathlib import Path
root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(root))

# %%
import json
from src.config import PROC_DIR, REPORTS_DIR
from src.report import render_report
context = json.loads((PROC_DIR / 'analysis_context.json').read_text(encoding='utf-8'))
out = render_report(context, REPORTS_DIR / 'business_report.md')
out
# Out:
# C:\Users\flavi\Anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# WindowsPath('C:/Users/flavi/Documents/GitHub/Tourism_Company_Delinquency/reports/business_report.md')
